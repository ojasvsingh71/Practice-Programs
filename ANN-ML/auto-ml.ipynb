# %%
path=r"D:\Practice-Programs\ANN-ML\Data\kidney_disease.csv"

# %%
import h2o
from h2o.automl import H2OAutoML

h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 24.0.2+12-54, mixed mode, sharing)
#   Starting server from D:\Programs\Python\Python310\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\OJASV\AppData\Local\Temp\tmpw191q_qc
#   JVM stdout: C:\Users\OJASV\AppData\Local\Temp\tmpw191q_qc\h2o_OJASV_started_from_python.out
#   JVM stderr: C:\Users\OJASV\AppData\Local\Temp\tmpw191q_qc\h2o_OJASV_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Asia/Kolkata
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.10
# H2O_cluster_version_age:    1 month and 18 days
# ...

# %%
import pandas as pd

df=pd.read_csv(path)
print(df.columns)
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
y=df['classification']
X=df.drop("classification",axis=1)
