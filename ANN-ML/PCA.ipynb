# %% [markdown]
# ### 1. Mean Centering :
#
# The mean of the data should be (0,0)
#
# -  Find mean of data then subtract every element from mean.
#   $$x_{i} = x_{i} - \bar{x}$$
#
# ### 2. Co variance Analysis
#
# $$
# \begin{split}
# Z &= \begin{bmatrix}
# x=a&b \\
# y=c&d
# \end{bmatrix} \\
# cov(x,y) &= \begin{bmatrix}
# cov(a,b) &
# \end{bmatrix}
# \end{split}
# $$
#
# ### 3. Eigen Value
#
# The max of the eigen value contains more information about the data than the lower values.
